# %% [markdown]
# # Preprocessing of diabetic_data.csv

# %%
import IPython
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.preprocessing import StandardScaler

# %%
ORIGINAL_DF = pd.read_csv("diabetic_data.csv",index_col=0, na_values='?', low_memory=False)
df = ORIGINAL_DF.copy(deep=True)

# %% [markdown]
# ### Examining Dataset

# %%
str(df)
# Out:
# '              patient_nbr             race  gender       age weight  \\\nencounter_id                                                          \n2278392           8222157        Caucasian  Female    [0-10)    NaN   \n149190           55629189        Caucasian  Female   [10-20)    NaN   \n64410            86047875  AfricanAmerican  Female   [20-30)    NaN   \n500364           82442376        Caucasian    Male   [30-40)    NaN   \n16680            42519267        Caucasian    Male   [40-50)    NaN   \n35754            82637451        Caucasian    Male   [50-60)    NaN   \n55842            84259809        Caucasian    Male   [60-70)    NaN   \n63768           114882984        Caucasian    Male   [70-80)    NaN   \n12522            48330783        Caucasian  Female   [80-90)    NaN   \n15738            63555939        Caucasian  Female  [90-100)    NaN   \n28236            89869032  AfricanAmerican  Female   [40-50)    NaN   \n36900            77391171  AfricanAmerican    Male   [60-70)    NaN   \n40926            85504905        Caucasian  Female   [40-50)    NaN   \n42570            77586282        Caucasian    Male   [80-90)    NaN   \n62256            49726791  AfricanAmerican  Female   [60-70)    NaN   \n73578            86328819  AfricanAmerican    Male   [60-70)    NaN   \n77076            92519352  AfricanAmerican    Male   [50-60)    NaN   \n84222           108662661        Caucasian  Female   [50-60)    NaN   \n89682           107389323  AfricanAmerican    Male   [70-80)    NaN   \n148530           69422211              NaN    Male   [70-80)    NaN   \n150006           22864131              NaN  Female   [50-60)    NaN   \n150048           21239181              NaN    Male   [60-70)    NaN   \n182796           63000108  AfricanAmerican  Female   [70-80)    NaN   \n183930          107400762        Caucasian  Female   [80-90)    NaN   \n216156           62718876  AfricanAmerican  Female   [70-80)    NaN   \n221634           21861756            Other  Female   [50-60)    NaN   \n236316           40523301        Caucasian    Male   [80-90)    NaN   \n248916          115196778        Caucasian  Female   [50-60)    NaN   \n250872           41606064        Caucasian    Male   [20-30)    NaN   \n252822           18196434        Caucasian  Female   [80-90)    NaN   \n...                   ...              ...     ...       ...    ...   \n443739152        90751788        Caucasian  Female   [60-70)    NaN   \n443775086       125764160        Caucasian  Female   [40-50)    NaN   \n443775482        95780439        Caucasian    Male   [70-80)    NaN   \n443775740        30656952  AfricanAmerican    Male   [70-80)    NaN   \n443778398       134647673        Caucasian    Male   [40-50)    NaN   \n443787128        58160520  AfricanAmerican    Male  [90-100)    NaN   \n443787512        52419276        Caucasian    Male   [70-80)    NaN   \n443793668        47293812        Caucasian    Male   [80-90)    NaN   \n443793992        43686936        Caucasian  Female   [80-90)    NaN   \n443797076       183766055        Caucasian    Male   [50-60)    NaN   \n443797298        89955270        Caucasian    Male   [70-80)    NaN   \n443804570        33230016        Caucasian  Female   [70-80)    NaN   \n443811536       189481478        Caucasian  Female   [40-50)    NaN   \n443816024       106392411        Caucasian  Female   [70-80)    NaN   \n443824292       138784172        Caucasian  Female   [80-90)    NaN   \n443835140       175326800        Caucasian    Male   [70-80)    NaN   \n443835512       139605341            Other  Female   [40-50)    NaN   \n443841992       184875899            Other    Male   [40-50)    NaN   \n443842016       183087545        Caucasian  Female   [70-80)    NaN   \n443842022       188574944            Other  Female   [40-50)    NaN   \n443842070       140199494            Other  Female   [60-70)    NaN   \n443842136       181593374        Caucasian  Female   [70-80)    NaN   \n443842340       120975314        Cauca ...

# %%
print('Dataset Readmitted distro: {}'.format(Counter(df["readmitted"])))
missingvalues = pd.DataFrame(df.isnull().sum(axis=0), columns = ['number_of_missing_values'])
missingvalues['feature'] = missingvalues.index
missingvalues = missingvalues[['feature','number_of_missing_values']].reset_index (drop = True)
missingvalues[missingvalues.number_of_missing_values > 0]
# Out:
# Dataset Readmitted distro: Counter({'NO': 54864, '>30': 35545, '<30': 11357})
#               feature  number_of_missing_values
# 1                race                      2273
# 4              weight                     98569
# 9          payer_code                     40256
# 10  medical_specialty                     49949
# 17             diag_1                        21
# 18             diag_2                       358
# 19             diag_3                      1423

# %%
# DECISION 1: We will classify between earlier readmissions and the rest
df['readmitted'] = df['readmitted'].apply(lambda x: 0 if x == "<30" else 1)

# %%
# DECISION 2: We will drop variables with a massive number of NAs
# DECISION 2.1: We will conserve a weight variable which indicates whether weight was measured or not, as it might be interesting for study
df['weight'] = df['weight'].apply(lambda x: 0 if pd.isna(x) else 1)
df = df.drop(['payer_code', 'medical_specialty'], axis = 1)

# %%
categ = []
numer = []
for col in df.columns:
    if df[col].dtype == object and col != "patient_nbr":
        categ.append(col)
    else:
        numer.append(col)
print("Categorical: ", categ)
print("Numerical: ", numer)
# Out:
# Categorical:  ['race', 'gender', 'age', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed']
# Numerical:  ['patient_nbr', 'weight', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses', 'readmitted']

# %%
categNoDiag = list(filter(lambda x: x != 'diag_1' and x != 'diag_2' and x != 'diag_3', categ))
for name in categNoDiag:
    print("Dataset "+ name + " distro: \n{}\n".format(Counter(df[name])))
# Out:
# Dataset race distro:
# Counter({'Caucasian': 76099, 'AfricanAmerican': 19210, nan: 2273, 'Hispanic': 2037, 'Other': 1506, 'Asian': 641})
#
# Dataset gender distro:
# Counter({'Female': 54708, 'Male': 47055, 'Unknown/Invalid': 3})
#
# Dataset age distro:
# Counter({'[70-80)': 26068, '[60-70)': 22483, '[50-60)': 17256, '[80-90)': 17197, '[40-50)': 9685, '[30-40)': 3775, '[90-100)': 2793, '[20-30)': 1657, '[10-20)': 691, '[0-10)': 161})
#
# Dataset max_glu_serum distro:
# Counter({'None': 96420, 'Norm': 2597, '>200': 1485, '>300': 1264})
#
# Dataset A1Cresult distro:
# Counter({'None': 84748, '>8': 8216, 'Norm': 4990, '>7': 3812})
#
# Dataset metformin distro:
# Counter({'No': 81778, 'Steady': 18346, 'Up': 1067, 'Down': 575})
#
# Dataset repaglinide distro:
# Counter({'No': 100227, 'Steady': 1384, 'Up': 110, 'Down': 45})
#
# Dataset nateglinide distro:
# Counter({'No': 101063, 'Steady': 668, 'Up': 24, 'Down': 11})
#
# Dataset chlorpropamide distro:
# Counter({'No': 101680, 'Steady': 79, 'Up': 6, 'Down': 1})
#
# Dataset glimepiride distro:
# Counter({'No': 96575, 'Steady': 4670, 'Up': 327, 'Down': 194})
#
# Dataset acetohexamide distro:
# Counter({'No': 101765, 'Steady': 1})
#
# Dataset glipizide distro:
# Counter({'No': 89080, 'Steady': 11356, 'Up': 770, 'Down': 560})
#
# Dataset glyburide distro:
# Counter({'No': 91116, 'Steady': 9274, 'Up': 812, 'Down': 564})
#
# Dataset tolbutamide distro:
# Counter({'No': 101743, 'Steady': 23})
#
# Dataset pioglitazone distro:
# Counter({'No': 94438, 'Steady': 6976, 'Up': 234, 'Down': 118})
#
# Dataset rosiglitazone distro:
# Counter({'No': 95401, 'Steady': 6100, 'Up': 178, 'Down': 87})
#
# Dataset acarbose distro:
# Counter({'No': 101458, 'Steady': 295, 'Up': 10, 'Down': 3})
#
# Dataset miglitol distro:
# Counter({'No': 101728, 'Steady': 31, 'Down': 5, 'Up': 2})
#
# Dataset troglitazone distro:
# Counter({'No': 101763, 'Steady': 3})
#
# Dataset tolazamide distro:
# Counter({'No': 101727, 'Steady': 38, 'Up': 1})
#
# Dataset examide distro:
# Counter({'No': 101766})
#
# Dataset citoglipton distro:
# Counter({'No': 101766})
#
# Dataset insulin distro:
# Counter({'No': 47383, 'Steady': 30849, 'Down': 12218, 'Up': 11316})
#
# Dataset glyburide-metformin distro:
# Counter({'No': 101060, 'Steady': 692, 'Up': 8, 'Down': 6})
#
# Dataset glipizide-metformin distro:
# Counter({'No': 101753, 'Steady': 13})
#
# Dataset glimepiride-pioglitazone distro:
# Counter({'No': 101765, 'Steady': 1})
#
# Dataset metformin-rosiglitazone distro:
# Counter({'No': 101764, 'Steady': 2})
#
# Dataset metformin-pioglitazone distro:
# Counter({'No': 101765, 'Steady': 1})
#
# Dataset change distro:
# Counter({'No': 54755, 'Ch': 47011})
#
# Dataset diabetesMed distro:
# Counter({'Yes': 78363, 'No': 23403})

# %%
#Decision 3: Drop citoglipton and examide. (constants)
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
#Decision 4: Input NA in unknown-gender records
df["gender"]=df["gender"].replace("Unknown/Invalid", np.NaN)

# %%
#Decision 5: reduction of admission_type_id, discharge_disposition_id, admission_source_id 
#As seen in study, some of these values SHOULD be grouped as they pretty much mean the same. (Urgent care, emergency and similar)
#Decision 5.1: discharge_disposition_id = 11 is death during hospitalisation. Not even interesting for tests
print("Previously:")
for name in ['admission_source_id', 'discharge_disposition_id', 'admission_type_id']:
    print("Dataset "+ name + " distro: \n{}".format(Counter(df[name])))
valid = list(set(df[df['discharge_disposition_id'] != 11].index))
df = df[df['discharge_disposition_id'] != 11]
    
df['admission_type_id'] = df['admission_type_id'].replace(2,1)
df['admission_type_id'] = df['admission_type_id'].replace(7,1)
df['admission_type_id'] = df['admission_type_id'].replace(6,5)
df['admission_type_id'] = df['admission_type_id'].replace(8,5)

df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(6,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(8,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(9,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(13,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(3,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(4,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(5,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(14,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(22,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(23,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(24,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(12,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(15,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(16,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(17,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(25,18)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(26,18)

df['admission_source_id'] = df['admission_source_id'].replace(2,1)
df['admission_source_id'] = df['admission_source_id'].replace(3,1)
df['admission_source_id'] = df['admission_source_id'].replace(5,4)
df['admission_source_id'] = df['admission_source_id'].replace(6,4)
df['admission_source_id'] = df['admission_source_id'].replace(10,4)
df['admission_source_id'] = df['admission_source_id'].replace(22,4)
df['admission_source_id'] = df['admission_source_id'].replace(25,4)
df['admission_source_id'] = df['admission_source_id'].replace(15,9)
df['admission_source_id'] = df['admission_source_id'].replace(17,9)
df['admission_source_id'] = df['admission_source_id'].replace(20,9)
df['admission_source_id'] = df['admission_source_id'].replace(21,9)
df['admission_source_id'] = df['admission_source_id'].replace(13,11)
df['admission_source_id'] = df['admission_source_id'].replace(14,11)
print("\n Now:")
for name in ['admission_source_id', 'discharge_disposition_id', 'admission_type_id']:
    print("Dataset "+ name + " distro: \n{}".format(Counter(df[name])))
# Out:
# Previously:
# Dataset admission_source_id distro:
# Counter({7: 57494, 1: 29565, 17: 6781, 4: 3187, 6: 2264, 2: 1104, 5: 855, 3: 187, 20: 161, 9: 125, 8: 16, 22: 12, 10: 8, 14: 2, 11: 2, 25: 2, 13: 1})
# Dataset discharge_disposition_id distro:
# Counter({1: 60234, 3: 13954, 6: 12902, 18: 3691, 2: 2128, 22: 1993, 11: 1642, 5: 1184, 25: 989, 4: 815, 7: 623, 23: 412, 13: 399, 14: 372, 28: 139, 8: 108, 15: 63, 24: 48, 9: 21, 17: 14, 16: 11, 19: 8, 10: 6, 27: 5, 12: 3, 20: 2})
# Dataset admission_type_id distro:
# Counter({1: 53990, 3: 18869, 2: 18480, 6: 5291, 5: 4785, 8: 320, 7: 21, 4: 10})
#
#  Now:
# Dataset admission_source_id distro:
# Counter({7: 56370, 1: 30592, 9: 6930, 4: 6212, 8: 15, 11: 5})
# Dataset discharge_disposition_id distro:
# Counter({1: 73664, 2: 20906, 18: 4680, 7: 623, 28: 139, 10: 97, 19: 8, 27: 5, 20: 2})
# Dataset admission_type_id distro:
# Counter({1: 71136, 3: 18740, 5: 10238, 4: 10})

# %%
# Decision 6: One-hot-encode A1Cresult and max_glu_serum into Normal and Abnormal. No-test = neither.
print("Previously:")
for name in ["A1Cresult", "max_glu_serum"]:
    print("Dataset "+ name + " distro: \n{}".format(Counter(df[name])))
    
df["A1C_Abnormal"] = df["A1Cresult"].apply(lambda x: 0 if x in ["Norm", "None"] else 1)
df["A1C_Normal"] = df["A1Cresult"].apply(lambda x: 1 if x == "Norm" else 0)

df["MAXGLU_Abnormal"] = df["max_glu_serum"].apply(lambda x: 0 if x in ["Norm", "None"] else 1)
df["MAXGLU_Normal"] = df["max_glu_serum"].apply(lambda x: 1 if x == "Norm" else 0)

print("\nNow:")
for name in ["A1C_Abnormal", "A1C_Normal", "MAXGLU_Abnormal", "MAXGLU_Normal"]:
    print("Dataset "+ name + " distro: \n{}".format(Counter(df[name])))
# Out:
# Previously:
# Dataset A1Cresult distro:
# Counter({'None': 83247, '>8': 8151, 'Norm': 4942, '>7': 3784})
# Dataset max_glu_serum distro:
# Counter({'None': 94899, 'Norm': 2574, '>200': 1440, '>300': 1211})
#
# Now:
# Dataset A1C_Abnormal distro:
# Counter({0: 88189, 1: 11935})
# Dataset A1C_Normal distro:
# Counter({0: 95182, 1: 4942})
# Dataset MAXGLU_Abnormal distro:
# Counter({0: 97473, 1: 2651})
# Dataset MAXGLU_Normal distro:
# Counter({0: 97550, 1: 2574})

# %%
# + Dropping of original:
df = df.drop(["max_glu_serum","A1Cresult"], axis=1)

# %%
# Decision 7: Age to numerical, ORDERED. (Same as inputting mean of interval)
df['age'] = df['age'].replace('[0-10)', 0)
df['age'] = df['age'].replace('[10-20)', 1)
df['age'] = df['age'].replace('[20-30)', 2)
df['age'] = df['age'].replace('[30-40)', 3)
df['age'] = df['age'].replace('[40-50)', 4)
df['age'] = df['age'].replace('[50-60)', 5)
df['age'] = df['age'].replace('[60-70)', 6)
df['age'] = df['age'].replace('[70-80)', 7)
df['age'] = df['age'].replace('[80-90)', 8)
df['age'] = df['age'].replace('[90-100)', 9)

# %%
df.head().T
# Out:
# encounter_id                2278392    149190           64410      500364   \
# patient_nbr                 8222157   55629189         86047875   82442376
# race                      Caucasian  Caucasian  AfricanAmerican  Caucasian
# gender                       Female     Female           Female       Male
# age                               0          1                2          3
# weight                            0          0                0          0
# admission_type_id                 5          1                1          1
# discharge_disposition_id         18          1                1          1
# admission_source_id               1          7                7          7
# time_in_hospital                  1          3                2          2
# num_lab_procedures               41         59               11         44
# num_procedures                    0          0                5          1
# num_medications                   1         18               13         16
# number_outpatient                 0          0                2          0
# number_emergency                  0          0                0          0
# number_inpatient                  0          0                1          0
# diag_1                       250.83        276              648          8
# diag_2                          NaN     250.01              250     250.43
# diag_3                          NaN        255              V27        403
# number_diagnoses                  1          9                6          7
# metformin                        No         No               No         No
# repaglinide                      No         No               No         No
# nateglinide                      No         No               No         No
# chlorpropamide                   No         No               No         No
# glimepiride                      No         No               No         No
# acetohexamide                    No         No               No         No
# glipizide                        No         No           Steady         No
# glyburide                        No         No               No         No
# tolbutamide                      No         No               No         No
# pioglitazone                     No         No               No         No
# rosiglitazone                    No         No               No         No
# acarbose                         No         No               No         No
# miglitol                         No         No               No         No
# troglitazone                     No         No               No         No
# tolazamide                       No         No               No         No
# insulin                          No         Up               No         Up
# glyburide-metformin              No         No               No         No
# glipizide-metformin              No         No               No         No
# glimepiride-pioglitazone         No         No               No         No
# metformin-rosiglitazone          No         No               No         No
# metformin-pioglitazone           No         No               No         No
# change                           No         Ch               No         Ch
# diabetesMed                      No        Yes              Yes        Yes
# readmitted                        1          1                1          1
# A1C_Abnormal                      0          0                0          0
# A1C_Normal                        0          0                0          0
# MAXGLU_Abnormal                   0          0                0          0
# MAXGLU_Normal                     0          0                0          0
#
# encounter_id                16680
# patient_nbr                42519267
# race                      Caucasian
# gender                         Male
# age                               4
# weight                            0
# admission_type_id                 1
# discharge_disposition_id          1
# admission_source_id               7
# time_in_hospital                  1
# num_lab_procedures               51
# num_procedures                    0
# num_medications                   8
# number_outpatient                 0
# number_emergency                  0
# number_inpatient                  0
# diag_1                          197
# diag_2                          157
# diag_3                          250
# number_diagnoses                  5
# metformin                        No
# repaglinide                      No
# nateglinide                      No
# chlorpropamide                   No
# glimepiride                      No
# acetohexamide                    No
# glipizide                    Steady
# glyburide                        No
# tolbutamide                      No
# pioglitazone                     No
# rosiglitazone                    No
# acarbose                         No
# miglitol                         No
# troglitazone                     No
# tolazamide                       No
# insulin                      Steady
# glyburide-metformin              No
# glipizide-metformin              No
# glimepiride-pioglitazone         No
# metformin-rosiglitazone          No
# metformin-pioglitazone           No
# change                           Ch
# diabetesMed                     Yes
# readmitted                        1
# A1C_Abnormal                      0
# A1C_Normal                        0
# MAXGLU_Abnormal                   0
# MAXGLU_Normal                     0

# %%
# Decision 8: One-hot encoding of gender:
df = df[df['gender'].notna()] # 3 cases, irrelevant to drop
df["Female"] = df['gender'].apply(lambda x: 1 if x == "Female" else 0)

# %%
#drop gender
df = df.drop(["gender"], axis=1)

# %%
df.head().T
# Out:
# encounter_id                2278392    149190           64410      500364   \
# patient_nbr                 8222157   55629189         86047875   82442376
# race                      Caucasian  Caucasian  AfricanAmerican  Caucasian
# age                               0          1                2          3
# weight                            0          0                0          0
# admission_type_id                 5          1                1          1
# discharge_disposition_id         18          1                1          1
# admission_source_id               1          7                7          7
# time_in_hospital                  1          3                2          2
# num_lab_procedures               41         59               11         44
# num_procedures                    0          0                5          1
# num_medications                   1         18               13         16
# number_outpatient                 0          0                2          0
# number_emergency                  0          0                0          0
# number_inpatient                  0          0                1          0
# diag_1                       250.83        276              648          8
# diag_2                          NaN     250.01              250     250.43
# diag_3                          NaN        255              V27        403
# number_diagnoses                  1          9                6          7
# metformin                        No         No               No         No
# repaglinide                      No         No               No         No
# nateglinide                      No         No               No         No
# chlorpropamide                   No         No               No         No
# glimepiride                      No         No               No         No
# acetohexamide                    No         No               No         No
# glipizide                        No         No           Steady         No
# glyburide                        No         No               No         No
# tolbutamide                      No         No               No         No
# pioglitazone                     No         No               No         No
# rosiglitazone                    No         No               No         No
# acarbose                         No         No               No         No
# miglitol                         No         No               No         No
# troglitazone                     No         No               No         No
# tolazamide                       No         No               No         No
# insulin                          No         Up               No         Up
# glyburide-metformin              No         No               No         No
# glipizide-metformin              No         No               No         No
# glimepiride-pioglitazone         No         No               No         No
# metformin-rosiglitazone          No         No               No         No
# metformin-pioglitazone           No         No               No         No
# change                           No         Ch               No         Ch
# diabetesMed                      No        Yes              Yes        Yes
# readmitted                        1          1                1          1
# A1C_Abnormal                      0          0                0          0
# A1C_Normal                        0          0                0          0
# MAXGLU_Abnormal                   0          0                0          0
# MAXGLU_Normal                     0          0                0          0
# Female                            1          1                1          0
#
# encounter_id                16680
# patient_nbr                42519267
# race                      Caucasian
# age                               4
# weight                            0
# admission_type_id                 1
# discharge_disposition_id          1
# admission_source_id               7
# time_in_hospital                  1
# num_lab_procedures               51
# num_procedures                    0
# num_medications                   8
# number_outpatient                 0
# number_emergency                  0
# number_inpatient                  0
# diag_1                          197
# diag_2                          157
# diag_3                          250
# number_diagnoses                  5
# metformin                        No
# repaglinide                      No
# nateglinide                      No
# chlorpropamide                   No
# glimepiride                      No
# acetohexamide                    No
# glipizide                    Steady
# glyburide                        No
# tolbutamide                      No
# pioglitazone                     No
# rosiglitazone                    No
# acarbose                         No
# miglitol                         No
# troglitazone                     No
# tolazamide                       No
# insulin                      Steady
# glyburide-metformin              No
# glipizide-metformin              No
# glimepiride-pioglitazone         No
# metformin-rosiglitazone          No
# metformin-pioglitazone           No
# change                           Ch
# diabetesMed                     Yes
# readmitted                        1
# A1C_Abnormal                      0
# A1C_Normal                        0
# MAXGLU_Abnormal                   0
# MAXGLU_Normal                     0
# Female                            0

# %%
# Decision 9: Meds will be re-mapped to 0 if he does not take it, 1 otherwise (independently of dosage change)   
meds = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin', 'tolazamide', 'metformin-pioglitazone','metformin-rosiglitazone', 'glimepiride-pioglitazone', 'glipizide-metformin', 'troglitazone', 'tolbutamide', 'acetohexamide']
for med in meds:
    df[med] = df[med].apply(lambda x: 0 if x =="No" else 1)

# %%
# Decision 10: We transform diagnosis_1 into a higher hierarchy (less classes) and one-hot encode it. Diag 2 and 3 worsen the results, so we drop them
df = df[df['diag_1'].notna()] # 21 cases, irrelevant to drop
df['temp_diag1'] = df['diag_1']
df.loc[df['diag_1'].str.contains('V', na=True), ['temp_diag1']] = -9 # there are no NAs, just a quick hack. Using neg numbers
df.loc[df['diag_1'].str.contains('E', na=True), ['temp_diag1']] = -9 # to avoid collision with rest when transforming

df['temp_diag1'] = df['temp_diag1'].astype(float)

df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -1 if (x >= 390 and x < 460) or (np.floor(x) == 785) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -2 if (x >= 460 and x < 520) or (np.floor(x) == 786) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -3 if (x >= 520 and x < 580) or (np.floor(x) == 787) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -4 if (np.floor(x) == 250) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -5 if (x >= 800 and x < 1000) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -6 if (x >= 710 and x < 740) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -7 if (x >= 580 and x < 630) or (np.floor(x) == 788) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -8 if (x >= 140 and x < 240) else x)
df["temp_diag1"] = df["temp_diag1"].apply(lambda x: -9 if (x >= 0) else x) #default

dummiesDiag1 = pd.get_dummies(-df['temp_diag1'], drop_first = False)
for d in list(dummiesDiag1):
    df["Diag_"+str(int(d))] = dummiesDiag1[d]
df = df.drop(["temp_diag1"], axis = 1)

# %%
# Drop diagnosis:
df = df.drop(["diag_1","diag_2", "diag_3"], axis=1)

# %%
df.head().T
# Out:
# encounter_id                2278392    149190           64410      500364   \
# patient_nbr                 8222157   55629189         86047875   82442376
# race                      Caucasian  Caucasian  AfricanAmerican  Caucasian
# age                               0          1                2          3
# weight                            0          0                0          0
# admission_type_id                 5          1                1          1
# discharge_disposition_id         18          1                1          1
# admission_source_id               1          7                7          7
# time_in_hospital                  1          3                2          2
# num_lab_procedures               41         59               11         44
# num_procedures                    0          0                5          1
# num_medications                   1         18               13         16
# number_outpatient                 0          0                2          0
# number_emergency                  0          0                0          0
# number_inpatient                  0          0                1          0
# number_diagnoses                  1          9                6          7
# metformin                         0          0                0          0
# repaglinide                       0          0                0          0
# nateglinide                       0          0                0          0
# chlorpropamide                    0          0                0          0
# glimepiride                       0          0                0          0
# acetohexamide                     0          0                0          0
# glipizide                         0          0                1          0
# glyburide                         0          0                0          0
# tolbutamide                       0          0                0          0
# pioglitazone                      0          0                0          0
# rosiglitazone                     0          0                0          0
# acarbose                          0          0                0          0
# miglitol                          0          0                0          0
# troglitazone                      0          0                0          0
# tolazamide                        0          0                0          0
# insulin                           0          1                0          1
# glyburide-metformin               0          0                0          0
# glipizide-metformin               0          0                0          0
# glimepiride-pioglitazone          0          0                0          0
# metformin-rosiglitazone           0          0                0          0
# metformin-pioglitazone            0          0                0          0
# change                           No         Ch               No         Ch
# diabetesMed                      No        Yes              Yes        Yes
# readmitted                        1          1                1          1
# A1C_Abnormal                      0          0                0          0
# A1C_Normal                        0          0                0          0
# MAXGLU_Abnormal                   0          0                0          0
# MAXGLU_Normal                     0          0                0          0
# Female                            1          1                1          0
# Diag_1                            0          0                0          0
# Diag_2                            0          0                0          0
# Diag_3                            0          0                0          0
# Diag_4                            1          0                0          0
# Diag_5                            0          0                0          0
# Diag_6                            0          0                0          0
# Diag_7                            0          0                0          0
# Diag_8                            0          0                0          0
# Diag_9                            0          1                1          1
#
# encounter_id                16680
# patient_nbr                42519267
# race                      Caucasian
# age                               4
# weight                            0
# admission_type_id                 1
# discharge_disposition_id          1
# admission_source_id               7
# time_in_hospital                  1
# num_lab_procedures               51
# num_procedures                    0
# num_medications                   8
# number_outpatient                 0
# number_emergency                  0
# number_inpatient                  0
# number_diagnoses                  5
# metformin                         0
# repaglinide                       0
# nateglinide                       0
# chlorpropamide                    0
# glimepiride                       0
# acetohexamide                     0
# glipizide                         1
# glyburide                         0
# tolbutamide                       0
# pioglitazone                      0
# rosiglitazone                     0
# acarbose                          0
# miglitol                          0
# troglitazone                      0
# tolazamide                        0
# insulin                           1
# glyburide-metformin               0
# glipizide-metformin               0
# glimepiride-pioglitazone          0
# metformin-rosiglitazone           0
# metformin-pioglitazone            0
# change                           Ch
# diabetesMed                     Yes
# readmitted                        1
# A1C_Abnormal                      0
# A1C_Normal                        0
# MAXGLU_Abnormal                   0
# MAXGLU_Normal                     0
# Female                            0
# Diag_1                            0
# Diag_2                            0
# Diag_3                            0
# Diag_4                            0
# Diag_5                            0
# Diag_6                            0
# Diag_7                            0
# Diag_8                            1
# Diag_9                            0

# %%
# Decision 11: Encode rest of categoricals (no ids yet)
df["change"] = df["change"].apply(lambda x: 0 if x== "No" else 1)
df["diabetesMed"] = df["diabetesMed"].apply(lambda x: 0 if x== "No" else 1)

# %%
# Decision 12: One hot encode Ids. admission_type_id, discharge_disposition_id, admission_source_id
dummiesADM_S = pd.get_dummies(df['admission_source_id'], drop_first = False)
for d in list(dummiesADM_S):
    df["ADM_S_"+str(d)] = dummiesADM_S[d]
dummiesADM_T = pd.get_dummies(df['admission_type_id'], drop_first = False)
for d in list(dummiesADM_T):
    df["ADM_T_"+str(d)] = dummiesADM_T[d]
dummiesDIS_D = pd.get_dummies(df['discharge_disposition_id'], drop_first = False)
for d in list(dummiesDIS_D):
    df["DIS_D_"+str(d)] = dummiesDIS_D[d]

# %%
df = df.drop(["admission_type_id","discharge_disposition_id", "admission_source_id"], axis=1)

# %%
df.head().T
# Out:
# encounter_id           2278392    149190           64410      500364   \
# patient_nbr            8222157   55629189         86047875   82442376
# race                 Caucasian  Caucasian  AfricanAmerican  Caucasian
# age                          0          1                2          3
# weight                       0          0                0          0
# time_in_hospital             1          3                2          2
# num_lab_procedures          41         59               11         44
# num_procedures               0          0                5          1
# num_medications              1         18               13         16
# number_outpatient            0          0                2          0
# number_emergency             0          0                0          0
# number_inpatient             0          0                1          0
# number_diagnoses             1          9                6          7
# metformin                    0          0                0          0
# repaglinide                  0          0                0          0
# nateglinide                  0          0                0          0
# chlorpropamide               0          0                0          0
# glimepiride                  0          0                0          0
# acetohexamide                0          0                0          0
# glipizide                    0          0                1          0
# glyburide                    0          0                0          0
# tolbutamide                  0          0                0          0
# pioglitazone                 0          0                0          0
# rosiglitazone                0          0                0          0
# acarbose                     0          0                0          0
# miglitol                     0          0                0          0
# troglitazone                 0          0                0          0
# tolazamide                   0          0                0          0
# insulin                      0          1                0          1
# glyburide-metformin          0          0                0          0
# glipizide-metformin          0          0                0          0
# ...                        ...        ...              ...        ...
# MAXGLU_Normal                0          0                0          0
# Female                       1          1                1          0
# Diag_1                       0          0                0          0
# Diag_2                       0          0                0          0
# Diag_3                       0          0                0          0
# Diag_4                       1          0                0          0
# Diag_5                       0          0                0          0
# Diag_6                       0          0                0          0
# Diag_7                       0          0                0          0
# Diag_8                       0          0                0          0
# Diag_9                       0          1                1          1
# ADM_S_1                      1          0                0          0
# ADM_S_4                      0          0                0          0
# ADM_S_7                      0          1                1          1
# ADM_S_8                      0          0                0          0
# ADM_S_9                      0          0                0          0
# ADM_S_11                     0          0                0          0
# ADM_T_1                      0          1                1          1
# ADM_T_3                      0          0                0          0
# ADM_T_4                      0          0                0          0
# ADM_T_5                      1          0                0          0
# DIS_D_1                      0          1                1          1
# DIS_D_2                      0          0                0          0
# DIS_D_7                      0          0                0          0
# DIS_D_10                     0          0                0          0
# DIS_D_18                     1          0                0          0
# DIS_D_19                     0          0                0          0
# DIS_D_20                     0          0                0          0
# DIS_D_27                     0          0                0          0
# DIS_D_28                     0          0                0          0
#
# encounter_id           16680
# patient_nbr           42519267
# race                 Caucasian
# age                          4
# weight                       0
# time_in_hospital             1
# num_lab_procedures          51
# num_procedures               0
# num_medications              8
# number_outpatient            0
# number_emergency             0
# number_inpatient             0
# number_diagnoses             5
# metformin                    0
# repaglinide                  0
# nateglinide                  0
# chlorpropamide               0
# glimepiride                  0
# acetohexamide                0
# glipizide                    1
# glyburide                    0
# tolbutamide                  0
# pioglitazone                 0
# rosiglitazone                0
# acarbose                     0
# miglitol                     0
# troglitazone                 0
# tolazamide                   0
# insulin                      1
# glyburide-metformin          0
# glipizide-metformin          0
# ...                        ...
# MAXGLU_Normal                0
# Female                       0
# Diag_1                       0
# Diag_2                       0
# Diag_3                       0
# Diag_4                       0
# Diag_5                       0
# Diag_6                       0
# Diag_7                       0
# Diag_8                       1
# Diag_9                       0
# ADM_S_1                      0
# ADM_S_4                      0
# ADM_S_7                      1
# ADM_S_8                      0
# ADM_S_9                      0
# ADM_S_11                     0
# ADM_T_1                      1
# ADM_T_3                      0
# ADM_T_4                      0
# ADM_T_5                      0
# DIS_D_1                      1
# DIS_D_2                      0
# DIS_D_7                      0
# DIS_D_10                     0
# DIS_D_18                     0
# DIS_D_19                     0
# DIS_D_20                     0
# DIS_D_27                     0
# DIS_D_28                     0
#
# [69 rows x 5 columns]

# %%
print(df.shape)
missingvalues = pd.DataFrame(df.isnull().sum(axis=0), columns = ['number_of_missing_values'])
missingvalues['feature'] = missingvalues.index
missingvalues = missingvalues[['feature','number_of_missing_values']].reset_index (drop = True)
missingvalues[missingvalues.number_of_missing_values > 0]
# Out:
# (100100, 69)
#   feature  number_of_missing_values
# 1    race                      2235

# %%
# DECISION 13: Drop all NAs from race
df = df[df['race'].notna()] 
dummiesRace = pd.get_dummies(df['race'], drop_first = False)

for race in list(dummiesRace):
    df["race_"+race] = dummiesRace[race]

# %%
df =df.drop("race", axis = 1)

# %%
#Drop patient_nbr, unuseful
df = df.drop("patient_nbr", axis=1)
df = df.drop("metformin-rosiglitazone", axis=1)

# %%
# One last look at data:
#df.head().T
pd.set_option('display.max_columns', 500)
df.describe(include="all")
# Out:
#                 age        weight  time_in_hospital  num_lab_procedures  \
# count  97865.000000  97865.000000      97865.000000        97865.000000
# mean       6.081868      0.030859          4.391713           42.919726
# std        1.595037      0.172936          2.976420           19.640470
# min        0.000000      0.000000          1.000000            1.000000
# 25%        5.000000      0.000000          2.000000           31.000000
# 50%        6.000000      0.000000          4.000000           44.000000
# 75%        7.000000      0.000000          6.000000           57.000000
# max        9.000000      1.000000         14.000000          132.000000
#
#        num_procedures  num_medications  number_outpatient  number_emergency  \
# count    97865.000000     97865.000000       97865.000000      97865.000000
# mean         1.331978        15.986624           0.373474          0.201839
# std          1.698432         8.084550           1.273538          0.945136
# min          0.000000         1.000000           0.000000          0.000000
# 25%          0.000000        10.000000           0.000000          0.000000
# 50%          1.000000        15.000000           0.000000          0.000000
# 75%          2.000000        20.000000           0.000000          0.000000
# max          6.000000        81.000000          42.000000         76.000000
#
#        number_inpatient  number_diagnoses     metformin   repaglinide  \
# count      97865.000000      97865.000000  97865.000000  97865.000000
# mean           0.640280          7.426342      0.198529      0.015501
# std            1.270368          1.930904      0.398894      0.123535
# min            0.000000          1.000000      0.000000      0.000000
# 25%            0.000000          6.000000      0.000000      0.000000
# 50%            0.000000          8.000000      0.000000      0.000000
# 75%            1.000000          9.000000      0.000000      0.000000
# max           21.000000         16.000000      1.000000      1.000000
#
#         nateglinide  chlorpropamide   glimepiride  acetohexamide  \
# count  97865.000000    97865.000000  97865.000000   97865.000000
# mean       0.007020        0.000858      0.050999       0.000010
# std        0.083491        0.029285      0.219996       0.003197
# min        0.000000        0.000000      0.000000       0.000000
# 25%        0.000000        0.000000      0.000000       0.000000
# 50%        0.000000        0.000000      0.000000       0.000000
# 75%        0.000000        0.000000      0.000000       0.000000
# max        1.000000        1.000000      1.000000       1.000000
#
#           glipizide     glyburide   tolbutamide  pioglitazone  rosiglitazone  \
# count  97865.000000  97865.000000  97865.000000  97865.000000   97865.000000
# mean       0.125888      0.105227      0.000204      0.072825       0.063240
# std        0.331724      0.306847      0.014294      0.259850       0.243396
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%        0.000000      0.000000      0.000000      0.000000       0.000000
# 50%        0.000000      0.000000      0.000000      0.000000       0.000000
# 75%        0.000000      0.000000      0.000000      0.000000       0.000000
# max        1.000000      1.000000      1.000000      1.000000       1.000000
#
#            acarbose      miglitol  troglitazone    tolazamide       insulin  \
# count  97865.000000  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.003076      0.000388      0.000031      0.000399      0.531988
# std        0.055374      0.019701      0.005537      0.019959      0.498978
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      1.000000
# 75%        0.000000      0.000000      0.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# count         97865.000000         97865.000000              97865.000000
# mean              0.006867             0.000133                  0.000010
# std               0.082580             0.011525                  0.003197
# min               0.000000             0.000000                  0.000000
# 25%               0.000000             0.000000                  0.000000
# 50%               0.000000             0.000000                  0.000000
# 75%               0.000000             0.000000                  0.000000
# max               1.000000             1.000000                  1.000000
#
#        metformin-pioglitazone        change   diabetesMed    readmitted  \
# count            97865.000000  97865.000000  97865.000000  97865.000000
# mean                 0.000010      0.463393      0.770592      0.885924
# std                  0.003197      0.498661      0.420454      0.317905
# min                  0.000000      0.000000      0.000000      0.000000
# 25%                  0.000000      0.000000      1.000000      1.000000
# 50%                  0.000000      0.000000      1.000000      1.000000
# 75%                  0.000000      1.000000      1.000000      1.000000
# max                  1.000000      1.000000      1.000000      1.000000
#
#        A1C_Abnormal    A1C_Normal  MAXGLU_Abnormal  MAXGLU_Normal  \
# count  97865.000000  97865.000000     97865.000000   97865.000000
# mean       0.118500      0.049619         0.026792       0.026036
# std        0.323201      0.217158         0.161476       0.159243
# min        0.000000      0.000000         0.000000       0.000000
# 25%        0.000000      0.000000         0.000000       0.000000
# 50%        0.000000      0.000000         0.000000       0.000000
# 75%        0.000000      0.000000         0.000000       0.000000
# max        1.000000      1.000000         1.000000       1.000000
#
#              Female        Diag_1        Diag_2        Diag_3        Diag_4  \
# count  97865.000000  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.538926      0.298493      0.140663      0.094038      0.086895
# std        0.498485      0.457599      0.347676      0.291883      0.281683
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              Diag_5        Diag_6        Diag_7        Diag_8        Diag_9  \
# count  97865.000000  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.068789      0.049180      0.050713      0.032923      0.178307
# std        0.253096      0.216245      0.219412      0.178436      0.382773
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             ADM_S_1       ADM_S_4       ADM_S_7       ADM_S_8       ADM_S_9  \
# count  97865.000000  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.304665      0.058591      0.567302      0.000153      0.069238
# std        0.460268      0.234859      0.495452      0.012379      0.253860
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      1.000000      0.000000      0.000000
# 75%        1.000000      0.000000      1.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ADM_S_11       ADM_T_1       ADM_T_3       ADM_T_4       ADM_T_5  \
# count  97865.000000  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.000051      0.708783      0.187789      0.000102      0.103326
# std        0.007148      0.454326      0.390546      0.010108      0.304386
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      1.000000      0.000000      0.000000      0.000000
# 75%        0.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             DIS_D_1       DIS_D_2       DIS_D_7      DIS_D_10      DIS_D_18  \
# count  97865.000000  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.735493      0.208266      0.006233      0.000991      0.047453
# std        0.441073      0.406070      0.078704      0.031467      0.212607
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            DIS_D_19      DIS_D_20      DIS_D_27      DIS_D_28  \
# count  97865.000000  97865.000000  97865.000000  97865.000000
# mean       0.000082      0.000020      0.000051      0.001410
# std        0.009041      0.004521      0.007148      0.037525
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000
#
#        race_AfricanAmerican    race_Asian  race_Caucasian  race_Hispanic  \
# count          97865.000000  97865.000000    97865.000000   97865.000000
# mean               0.192909      0.006458        0.764798       0.020661
# std                0.394584      0.080101        0.424127       0.142248
# min                0.000000      0.000000        0.000000       0.000000
# 25%                0.000000      0.000000        1.000000       0.000000
# 50%                0.000000      0.000000        1.000000       0.000000
# 75%                0.000000      0.000000        1.000000       0.000000
# max                1.000000      1.000000        1.000000       1.000000
#
#          race_Other
# count  97865.000000
# mean       0.015174
# std        0.122245
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ## Train_test splitting

# %%
# We should only deal with race missings AFTER the split. We will also make a very simple classifier for inputting the race.
inputSet = df.drop("readmitted", axis=1)
outputSet = df["readmitted"]
X_train, X_test, y_train, y_test = train_test_split(inputSet, outputSet, random_state=42,test_size=0.3)

# %% [markdown]
# ### Standarization and logarithmic transformations

# %%
numericInterestingVariables =['age', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses']
for var in numericInterestingVariables:
    if (abs(X_train[var].skew()) >2) & (abs(X_train[var].kurtosis()) >2):
        print(var, " needs log")
# Out:
# number_outpatient  needs log
# number_emergency  needs log
# number_inpatient  needs log

# %%
#DECISION 14: Applying logarithmics to these variables
X_train["number_outpatient"] =  np.log1p(X_train["number_outpatient"])
X_train["number_emergency"] =  np.log1p(X_train["number_emergency"])
X_train["number_inpatient"] =  np.log1p(X_train["number_inpatient"])

X_test["number_outpatient"] =  np.log1p(X_test["number_outpatient"])
X_test["number_emergency"] =  np.log1p(X_test["number_emergency"])
X_test["number_inpatient"] =  np.log1p(X_test["number_inpatient"])
# Out:
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#df.describe().T
maxes = df.describe().T["max"]
Numeric = maxes[maxes!=1.0].index.tolist()
df[Numeric].describe().T
# Out:
#                       count       mean        std  min   25%   50%   75%  \
# age                 97865.0   6.081868   1.595037  0.0   5.0   6.0   7.0
# time_in_hospital    97865.0   4.391713   2.976420  1.0   2.0   4.0   6.0
# num_lab_procedures  97865.0  42.919726  19.640470  1.0  31.0  44.0  57.0
# num_procedures      97865.0   1.331978   1.698432  0.0   0.0   1.0   2.0
# num_medications     97865.0  15.986624   8.084550  1.0  10.0  15.0  20.0
# number_outpatient   97865.0   0.373474   1.273538  0.0   0.0   0.0   0.0
# number_emergency    97865.0   0.201839   0.945136  0.0   0.0   0.0   0.0
# number_inpatient    97865.0   0.640280   1.270368  0.0   0.0   0.0   1.0
# number_diagnoses    97865.0   7.426342   1.930904  1.0   6.0   8.0   9.0
#
#                       max
# age                   9.0
# time_in_hospital     14.0
# num_lab_procedures  132.0
# num_procedures        6.0
# num_medications      81.0
# number_outpatient    42.0
# number_emergency     76.0
# number_inpatient     21.0
# number_diagnoses     16.0

# %%
#Decision 15: Standarization of numerical variables (not binary)
scaler = StandardScaler().fit(X_train[Numeric])
X_train[Numeric] = scaler.transform(X_train[Numeric])
X_test[Numeric]  = scaler.transform(X_test[Numeric])
# Out:
# C:\Users\Victor\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Victor\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Victor\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
X_train.head()
X_train[Numeric].describe().T
# Out:
#                       count          mean       std       min       25%  \
# age                 68505.0 -2.775728e-16  1.000007 -3.825560 -0.681085
# time_in_hospital    68505.0 -3.095124e-16  1.000007 -1.140566 -0.804003
# num_lab_procedures  68505.0 -1.011325e-15  1.000007 -2.139982 -0.610690
# num_procedures      68505.0  8.670371e-16  1.000007 -0.785799 -0.785799
# num_medications     68505.0  1.252645e-16  1.000007 -1.853779 -0.742479
# number_outpatient   68505.0  5.535881e-16  1.000007 -0.402535 -0.402535
# number_emergency    68505.0  2.480981e-16  1.000007 -0.326184 -0.326184
# number_inpatient    68505.0  2.488433e-15  1.000007 -0.641890 -0.641890
# number_diagnoses    68505.0  1.216213e-16  1.000007 -3.328737 -0.739071
#
#                          50%       75%        max
# age                -0.052190  0.576705   1.834495
# time_in_hospital   -0.130877  0.542250   3.234756
# num_lab_procedures  0.052003  0.714696   4.537924
# num_procedures     -0.198719  0.388362   2.736683
# num_medications    -0.125091  0.492298   8.024437
# number_outpatient  -0.402535 -0.402535   8.306451
# number_emergency   -0.326184 -0.326184  13.345836
# number_inpatient   -0.641890  0.711977   5.395589
# number_diagnoses    0.296796  0.814729   4.440262

# %%
FinalTrainDataset = X_train
FinalTrainDataset["readmitted"] = y_train
FinalTestDataset = X_test
FinalTestDataset["readmitted"] = y_test
# Out:
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
FinalTrainDataset.to_csv('./Train.csv')
FinalTestDataset.to_csv('./Test.csv')
